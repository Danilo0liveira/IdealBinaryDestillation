# %%
import numpy as np

from scipy.optimize import fsolve, root
from column_model import ss_column
import model_parameters
import matplotlib.pyplot as plt

# %%
x0 = np.random.random(model_parameters.num_stages)

x = root(ss_column, x0, args=(2.74,), method='krylov')
print(x.x)

plt.plot(x.x)
plt.show()
# Out:
# [0.99669275 0.99504734 0.99294641 0.99026813 0.98686078 0.98253709
#  0.97706863 0.97018096 0.96155097 0.95080845 0.93754466 0.92133147
#  0.90175448 0.87846268 0.85123365 0.82004782 0.78515795 0.74713334
#  0.7068574  0.66546508 0.62422405 0.62064889 0.61592696 0.60971641
#  0.60159273 0.59104261 0.57746834 0.56021092 0.5386018  0.51205262
#  0.48018463 0.44298402 0.40094585 0.35514903 0.30720544 0.25906215
#  0.2126986  0.16981296 0.13159829 0.09866246 0.07108215]
